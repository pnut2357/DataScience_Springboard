# %%
# import sys
# !{sys.executable} -m pip install -U turicreate

# %%
import turicreate as tc
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data = tc.SFrame('updated_ski_data.csv')
data
# Out:
# Finished parsing file /Users/Jae/Google_Drive_jae0325/DATA_SCIENCE/Portfolio/projects/springboard_projects/Big_Mountain/updated_ski_data.csv
# Parsing completed. Parsed 100 lines in 0.048179 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str,int,int,int,int,int,int,int,int,int,int,int,int,int,int,float,int,int,int,int,int,int,int,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /Users/Jae/Google_Drive_jae0325/DATA_SCIENCE/Portfolio/projects/springboard_projects/Big_Mountain/updated_ski_data.csv
# Parsing completed. Parsed 330 lines in 0.010546 secs.
# Columns:
# 	Name	str
# 	Region	str
# 	state	str
# 	summit_elev	int
# 	vertical_drop	int
# 	base_elev	int
# 	trams	int
# 	fastEight	int
# 	fastSixes	int
# ...

# %%
data.show()
# Out:
# Materializing SFrame
# ...

# %%
tc.visualization.set_target='gui'

# %%
data['summit_elev'].show()
# Out:
# Materializing SArray
# ...
