# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
#!pip install matplotlib
# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"
# !pip install xlrd

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %%
# !pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in /Users/Jae/.pyenv/versions/3.7.3/lib/python3.7/site-packages (20.1.1)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties
# Out:
#     Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0          NaT      E09000001          E09000002  E09000003  E09000004
# 1   1995-01-01          91449            50460.2    93284.5    64958.1
# 2   1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3   1995-03-01        79120.7              51269    92247.5    64367.5
# 4   1995-04-01        77101.2            53133.5    90762.9    64277.7
# ..         ...            ...                ...        ...        ...
# 299 2019-11-01         776894             306390     522639     333657
# 300 2019-12-01         737275             301283     519306     336302
# 301 2020-01-01         757377             304187     520115     334430
# 302 2020-02-01         765416             304719     520966     334845
# 303 2020-03-01         792583             327136     532569     331679
#
#          Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# ...

# %%
print(len(properties))
print(properties.columns)
# Out:
# 304
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
# Checks type of variable properties
print(type(properties))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
proper_col_properties = properties.transpose()
proper_col_properties.tail()
# Out:
#                    0        1        2        3        4        5        6    \
# LONDON       E12000007  74435.8  72777.9  73896.8  74455.3    75432  75606.2
# SOUTH EAST   E12000008  64018.9    63715  64113.6  64623.2  64530.4    65511
# SOUTH WEST   E12000009  54705.2  54356.1  53583.1    54786  54698.8  54420.2
# Unnamed: 47        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# England      E92000001  53202.8  53096.2  53201.3  53590.9  53678.2  53735.2
#
#                  7        8        9    ...     294     295     296     297  \
# LONDON       75984.2  75529.3  74940.8  ...  470878  478858  472872  477779
# SOUTH EAST   65224.9  64851.6  64352.5  ...  321041  322863  323122  324357
# SOUTH WEST   54265.9  54365.7    54244  ...  252946  258449  258241  258751
# Unnamed: 47      NaN      NaN      NaN  ...     NaN     NaN     NaN     NaN
# England      53900.6  53600.3  53309.2  ...  246014  248652  249294  249771
#
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
cleaned_properties = proper_col_properties.reset_index()
cleaned_properties.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# ...

# %%
cleaned_properties.loc[0,0]
# Out:
# NaT

# %%
# rename a single (or partial) column(s) 
cleaned_properties.rename(columns={3:'changed_col'}, inplace=True)
# replace the names of the 1st and of 2nd values at the 1st row. 
cleaned_properties.replace({'index':{'Unnamed: 0':'London_District'}, 0:{pd.NaT:'ID'}}, inplace=True)
cleaned_properties.head(3)
# Out:
#                 index          0                    1                    2  \
# 0     London_District         ID  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
#
#            changed_col                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
#
#                    294                  295                  296  \
# ...

# %%
# rename every column.
new_index = ["%03d"% name for name in range(len(properties))]
new_index.insert(0, 'INDEX')
cleaned_properties.set_axis(new_index, axis='columns', inplace=True)
cleaned_properties.head(3)
# Out:
#                 INDEX        000                  001                  002  \
# 0     London_District         ID  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
#
#                    003                  004                  005  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
#
#                    006                  007                  008  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
#
#                    294                  295                  296  \
# ...

# %%
# Replace the first row as index.
cleaned_properties.columns = cleaned_properties.loc[0]
cleaned_properties.head(3)
# Out:
# 0     London_District         ID  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0     London_District         ID  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
#
# 0  2019-06-01 00:00:00  2019-07-01 00:00:00  2019-08-01 00:00:00  \
# ...

# %%
# There are meaningful data
cleaned_properties.tail(3)
# Out:
# 0  London_District         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 46      SOUTH WEST  E12000009             54705.2             54356.1
# 47     Unnamed: 47         ID                 NaN                 NaN
# 48         England  E92000001             53202.8             53096.2
#
# 0  1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 46             53583.1               54786             54698.8
# 47                 NaN                 NaN                 NaN
# 48             53201.3             53590.9             53678.2
#
# 0  1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 46             54420.2             54265.9             54365.7  ...
# 47                 NaN                 NaN                 NaN  ...
# 48             53735.2             53900.6             53600.3  ...
#
# 0  2019-06-01 00:00:00 2019-07-01 00:00:00 2019-08-01 00:00:00  \
# 46              252946              258449              258241
# ...

# %%
# Drop all non-meaningful data
cleaned_properties = cleaned_properties.dropna(how='any', inplace=False)
# same as: cleaned_properties.dropna(how='any', inplace=True)
# 'inplace=True' helps that users no need to assign back to dataframe (because it is on the same copy)

# Drop the first row of the data
cleaned_properties = cleaned_properties.drop(0, axis='index')
cleaned_properties.head(3)
# Out:
# 0     London_District         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# 2             53700.3             52113.1             52232.2  ...
# 3             90107.2             91441.2             92361.3  ...
#
# 0 2019-06-01 00:00:00 2019-07-01 00:00:00 2019-08-01 00:00:00  \
# 1              761526              756407              813770
# ...

# %%
# Check if the rows that contain nan are dropped.
cleaned_properties.tail(3)
# Out:
# 0  London_District         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 45      SOUTH EAST  E12000008             64018.9               63715
# 46      SOUTH WEST  E12000009             54705.2             54356.1
# 48         England  E92000001             53202.8             53096.2
#
# 0  1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 45             64113.6             64623.2             64530.4
# 46             53583.1               54786             54698.8
# 48             53201.3             53590.9             53678.2
#
# 0  1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 45               65511             65224.9             64851.6  ...
# 46             54420.2             54265.9             54365.7  ...
# 48             53735.2             53900.6             53600.3  ...
#
# 0  2019-06-01 00:00:00 2019-07-01 00:00:00 2019-08-01 00:00:00  \
# 45              321041              322863              323122
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
cleaned_properties = pd.melt(cleaned_properties, id_vars=['London_District', 'ID'])
cleaned_properties.rename(columns={0:'Date', 'value':'Ave'}, inplace=True)

cleaned_properties.head(5)
# Out:
#       London_District         ID       Date      Ave
# 0      City of London  E09000001 1995-01-01    91449
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.2
# 2              Barnet  E09000003 1995-01-01  93284.5
# 3              Bexley  E09000004 1995-01-01  64958.1
# 4               Brent  E09000005 1995-01-01  71306.6

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
cleaned_properties.loc[:,'Ave']
# Same as: cleaned_properties.iloc[:,2]
# Out:
# 0          91449
# 1        50460.2
# 2        93284.5
# 3        64958.1
# 4        71306.6
#           ...
# 13630     291254
# 13631     485794
# 13632     323353
# 13633     263360
# 13634     248271
# Name: Ave, Length: 13635, dtype: object

# %%
# Check the data at row 3.
print(cleaned_properties.iloc[[3]])

# Check if the Ave at row 3 is float.
print(type(cleaned_properties.loc[3, 'Ave']))

# Check the type of each column
print(cleaned_properties.dtypes)
print(cleaned_properties.info())

cleaned_properties['Ave'] = pd.to_numeric(cleaned_properties['Ave'], downcast='float')

# Check if the type of each column is changed
print(cleaned_properties.dtypes)
# Out:
#   London_District         ID       Date      Ave
# 3          Bexley  E09000004 1995-01-01  64958.1
# <class 'float'>
# London_District            object
# ID                         object
# Date               datetime64[ns]
# Ave                        object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13635 entries, 0 to 13634
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   London_District  13635 non-null  object
#  1   ID               13635 non-null  object
#  2   Date             13635 non-null  datetime64[ns]
#  3   Ave              13635 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 426.2+ KB
# None
# London_District            object
# ID                         object
# Date               datetime64[ns]
# Ave                       float32
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
print(cleaned_properties['London_District'].unique())
print()
print('length of unique London district:', len(cleaned_properties['London_District'].unique()))
# Out:
# ['City of London' 'Barking & Dagenham' 'Barnet' 'Bexley' 'Brent' 'Bromley'
#  'Camden' 'Croydon' 'Ealing' 'Enfield' 'Greenwich' 'Hackney'
#  'Hammersmith & Fulham' 'Haringey' 'Harrow' 'Havering' 'Hillingdon'
#  'Hounslow' 'Islington' 'Kensington & Chelsea' 'Kingston upon Thames'
#  'Lambeth' 'Lewisham' 'Merton' 'Newham' 'Redbridge' 'Richmond upon Thames'
#  'Southwark' 'Sutton' 'Tower Hamlets' 'Waltham Forest' 'Wandsworth'
#  'Westminster' 'Inner London' 'Outer London' 'NORTH EAST' 'NORTH WEST'
#  'YORKS & THE HUMBER' 'EAST MIDLANDS' 'WEST MIDLANDS' 'EAST OF ENGLAND'
#  'LONDON' 'SOUTH EAST' 'SOUTH WEST' 'England']
#
# length of unique London district: 45

# %%
# A list of non-district. 
non_district_list = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

proper_district_properties = cleaned_properties[~cleaned_properties['London_District'].isin(non_district_list)]

# Check if there is non-district in the proper_district_properties.
print(proper_district_properties['London_District'].isin(non_district_list).eq(False).all())
# finally_cleaned_properties
# Out:
# True

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
proper_district_properties.head(2)
# Out:
#       London_District         ID       Date           Ave
# 0      City of London  E09000001 1995-01-01  91448.984375
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.226562

# %%
# Too many districts: need to choose reasonable and meaningful London districts. 
ax = proper_district_properties.plot(kind ='line', x = 'Date', y='Ave')
ax.set_ylabel('Ave_Price')
# Out:
# Text(0, 0.5, 'Ave_Price')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
proper_district_properties['Year'] = proper_district_properties['Date'].apply(lambda t: t.year)
proper_district_properties.tail(3)
# Out:
# /Users/Jae/.pyenv/versions/3.7.3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       London_District         ID       Date           Ave  Year
# 13620  Waltham Forest  E09000031 2020-03-01  4.371533e+05  2020
# 13621      Wandsworth  E09000032 2020-03-01  6.248581e+05  2020
# 13622     Westminster  E09000033 2020-03-01  1.085013e+06  2020

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
district_list = proper_district_properties['London_District'].unique()
yearly_ave_properties = proper_district_properties.groupby(by=['London_District', 'Year']).mean()
print(yearly_ave_properties.loc[('City of London', 1995)])
print()
print(district_list)
# Out:
# Ave    99085.007812
# Name: (City of London, 1995), dtype: float32
#
# ['City of London' 'Barking & Dagenham' 'Barnet' 'Bexley' 'Brent' 'Bromley'
#  'Camden' 'Croydon' 'Ealing' 'Enfield' 'Greenwich' 'Hackney'
#  'Hammersmith & Fulham' 'Haringey' 'Harrow' 'Havering' 'Hillingdon'
#  'Hounslow' 'Islington' 'Kensington & Chelsea' 'Kingston upon Thames'
#  'Lambeth' 'Lewisham' 'Merton' 'Newham' 'Redbridge' 'Richmond upon Thames'
#  'Southwark' 'Sutton' 'Tower Hamlets' 'Waltham Forest' 'Wandsworth'
#  'Westminster']

# %%
yearly_ave_properties.head(5)
# Out:
#                                   Ave
# London_District    Year
# Barking & Dagenham 1995  51817.968750
#                    1996  51718.191406
#                    1997  55974.261719
#                    1998  60285.820312
#                    1999  65320.933594

# %%
print(yearly_ave_properties.loc['Barking & Dagenham'].Ave.array)
# Out:
# <PandasArray>
# [  51817.97,   51718.19,   55974.26,   60285.82,  65320.934,  77549.516,
#    88664.06, 112221.914,  142498.92,  158175.98,  163360.78,  167853.34,
#   184909.81,  187356.86,   156446.9,   166560.7,  163465.14,   165863.9,
#   173733.62,  201172.23,  233460.11,  273919.62,  287734.72,   295196.7,
#    298620.2,  312014.16]
# Length: 26, dtype: float32

# %%
# %matplotlib inline

# %%
## Too much data
plt.figure()


for region, year in yearly_ave_properties.index:
    yearly_ave_properties.loc[region].Ave.plot()
    plt.legend(region)

plt.xlabel('year')
plt.ylabel('Ave')    
plt.show()

# %%
# Here's where you should write your function:
def create_price_ratio(d, yr_from, yr_to):
    y_from = float(d['Ave'][d['Year']==yr_from])
    y_to = float(d['Ave'][d['Year']==yr_to])
    ratio = [y_to/y_from]
    return ratio

# %%
#  Test out the function by calling it with the following argument:
yearly_ave_properties = yearly_ave_properties.reset_index()
yearly_ave_properties['London_District']
create_price_ratio(yearly_ave_properties[yearly_ave_properties['London_District']=='Barking & Dagenham'], 2018, 2020)
# Out:
# [1.0569703843644926]

# %%
# We want to do this for all of the London Boroughs. 
# First, let's make an empty dictionary, called final, where we'll store our ratios for each unique London_Borough.
final = {}

# %%
# Now let's declare a for loop that will iterate through each of the unique elements of the 'London_Borough' column of our DataFrame dfg.
# Call the iterator variable 'b'. 
for b in yearly_ave_properties['London_District'].unique():
    # Let's make our parameter to our create_price_ratio function: i.e., we subset dfg on 'London_Borough' == b. 
    District = yearly_ave_properties[yearly_ave_properties['London_District'] == b]
    # Make a new entry in the final dictionary whose value's the result of calling create_price_ratio with the argument: borough
    final[b] = create_price_ratio(District, 1998, 2020)
# We use the function and incorporate that into a new key of the dictionary 
print(final)
# Out:
# {'Barking & Dagenham': [5.175581167057707], 'Barnet': [4.2869592999928745], 'Bexley': [4.13795543759855], 'Brent': [4.446545689960439], 'Bromley': [4.007620985819305], 'Camden': [4.914514283747467], 'City of London': [5.213686535660971], 'Croydon': [4.16730617683417], 'Ealing': [4.15933736385347], 'Enfield': [4.18385623825724], 'Greenwich': [4.95597178134297], 'Hackney': [6.734354490912976], 'Hammersmith & Fulham': [4.265431834179467], 'Haringey': [5.20777984108937], 'Harrow': [3.949254867538057], 'Havering': [4.19585606257587], 'Hillingdon': [4.198777943735246], 'Hounslow': [4.1497812766276745], 'Islington': [4.917637971033601], 'Kensington & Chelsea': [4.900875768177861], 'Kingston upon Thames': [4.2474865378406985], 'Lambeth': [5.113813379902834], 'Lewisham': [5.500763005560348], 'Merton': [4.675678227832029], 'Newham': [5.5805834339557165], 'Redbridge': [4.465312039509853], 'Richmond upon Thames': [4.010638603887474], 'Southwark': [5.444804144731939], 'Sutton': [4.06661088837311]
# ...

# %%
# Make a variable called df_ratios, and assign it the result of calling the DataFrame method on the dictionary final. 
price_ratios = pd.DataFrame(final)
price_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            5.175581  4.286959  4.137955  4.446546  4.007621  4.914514
#
#    City of London   Croydon    Ealing   Enfield  ...    Merton    Newham  \
# 0        5.213687  4.167306  4.159337  4.183856  ...  4.675678  5.580583
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.465312              4.010639   5.444804  4.066611       4.872998
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.827715    4.881092     5.474464
#
# [1 rows x 33 columns]

# %%
# All we need to do now is transpose it, and reset the index! 
Transposed_price_ratios = price_ratios.T
proper_ratios = Transposed_price_ratios.reset_index()
proper_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  5.175581
# 1              Barnet  4.286959
# 2              Bexley  4.137955
# 3               Brent  4.446546
# 4             Bromley  4.007621

# %%
# Let's just rename the 'index' column as 'London_Borough', and the '0' column to '2018'.
proper_ratios.rename(columns={'index':'District', 0:'2020'}, inplace=True)
proper_ratios.head()
# Out:
#              District      2020
# 0  Barking & Dagenham  5.175581
# 1              Barnet  4.286959
# 2              Bexley  4.137955
# 3               Brent  4.446546
# 4             Bromley  4.007621

# %%
ratios_list = proper_ratios.sort_values(by='2020',ascending=False)
ax = ratios_list[['District','2020']].plot(kind='bar')
ax.set_xticklabels(ratios_list.District)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(0, 0, 'Waltham Forest'),
#  Text(0, 0, 'Newham'),
#  Text(0, 0, 'Lewisham'),
#  Text(0, 0, 'Westminster'),
#  Text(0, 0, 'Southwark'),
#  Text(0, 0, 'City of London'),
#  Text(0, 0, 'Haringey'),
#  Text(0, 0, 'Barking & Dagenham'),
#  Text(0, 0, 'Lambeth'),
#  Text(0, 0, 'Greenwich'),
#  Text(0, 0, 'Islington'),
#  Text(0, 0, 'Camden'),
#  Text(0, 0, 'Kensington & Chelsea'),
#  Text(0, 0, 'Wandsworth'),
#  Text(0, 0, 'Tower Hamlets'),
#  Text(0, 0, 'Merton'),
#  Text(0, 0, 'Redbridge'),
#  Text(0, 0, 'Brent'),
#  Text(0, 0, 'Barnet'),
#  Text(0, 0, 'Hammersmith & Fulham'),
#  Text(0, 0, 'Kingston upon Thames'),
#  Text(0, 0, 'Hillingdon'),
#  Text(0, 0, 'Havering'),
#  Text(0, 0, 'Enfield'),
#  Text(0, 0, 'Croydon'),
#  Text(0, 0, 'Ealing'),
#  Text(0, 0, 'Hounslow'),
#  Text(0, 0, 'Bexley'),
#  Text(0, 0, 'Sutton'),
#  Text(0, 0, 'Richmond upon Thames'),
#  Text(0, 0, 'Bromley'),
#  Text(0, 0, 'Harrow')]

# %%
# Filter top15 restricts of housing price change from 1995 to 2020 
# by sorting the ratios dataframe in descending order.

top15 = proper_ratios.sort_values(by='2020',ascending=False).head(15)
top15
#ratioPlot = top15[['District','2020']].plot(kind='bar')
#ratioPlot.set_xticklabels(top15.District)
# Out:
#                 District      2020
# 11               Hackney  6.734354
# 30        Waltham Forest  5.827715
# 24                Newham  5.580583
# 22              Lewisham  5.500763
# 32           Westminster  5.474464
# 27             Southwark  5.444804
# 6         City of London  5.213687
# 13              Haringey  5.207780
# 0     Barking & Dagenham  5.175581
# 21               Lambeth  5.113813
# 10             Greenwich  4.955972
# 18             Islington  4.917638
# 5                 Camden  4.914514
# 19  Kensington & Chelsea  4.900876
# 31            Wandsworth  4.881092

# %%
# for region in top15['District']:
#     print(region)
yearly_ave_properties[yearly_ave_properties['London_District']=='Barking & Dagenham'].plot(x='Year', y='Ave')
plt.legend('Barking & Dagenham')
plt.xlabel('year')
plt.ylabel('Price Ave')    
plt.show()

# %%
# Concatenate top15 districts and assign them to variable top15_properties.
top15_properties = pd.DataFrame(columns=['London_District', 'Year', 'Ave'])
top15_list = []

for region in top15['District']: 
    temp = yearly_ave_properties[yearly_ave_properties['London_District']==region]
    top15_list.append(temp)
    
top15_properties = pd.concat(top15_list)

# Checks if all the elements are stored: 26 elements (i.e. 2020-1995) * 15 districts
print(len(top15_properties))
print(26*15)
# Out:
# 390
# 390

# %%
# reset index.
top15_properties.index = range(len(top15_properties.index))

top15_properties#.at[0, 'London_District']
# Out:
#     London_District  Year            Ave
# 0           Hackney  1995   66024.476562
# 1           Hackney  1996   69247.656250
# 2           Hackney  1997   78176.796875
# 3           Hackney  1998   87869.539062
# 4           Hackney  1999  105532.968750
# ..              ...   ...            ...
# 385      Wandsworth  2016  608740.937500
# 386      Wandsworth  2017  617921.500000
# 387      Wandsworth  2018  596649.125000
# 388      Wandsworth  2019  588613.062500
# 389      Wandsworth  2020  612122.125000
#
# [390 rows x 3 columns]

# %%
#top15_properties[top15_properties['London_District']=='Hackney']

# %%
## Yearly trend plot
plt.figure()

for region in top15_properties['London_District'].unique():
    #print(region)
    x=top15_properties[top15_properties['London_District']==region].Year
    y=top15_properties[top15_properties['London_District']==region].Ave
    plt.plot(x, y, label=region)
    #top15_properties[top15_properties['London_District']==region].plot(x='Year', y='Ave', kind='line', label=region)

plt.title('Housing Price for top15 District in London', fontweight="bold")
# bbox_to_anchor makes legend outside of the figure (x_location, y_location)
plt.legend(bbox_to_anchor=(1,1.05), loc='best')
plt.xlabel('year')
plt.ylabel('Housing Ave Price')    
plt.show()

## Ratio plot
another_plot = top15.plot.bar(x='District', y='2020')
another_plot.set_title('Ratios of Housing Price for top15 District in London', fontweight="bold")
another_plot.set_xticklabels(top15.District)
another_plot.set_ylabel('Ratio of y2020/y1995')
# Out:
# Text(0, 0.5, 'Ratio of y2020/y1995')

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
